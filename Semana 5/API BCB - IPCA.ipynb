# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# 433 é o código do IPCA

url = 'http://api.bcb.gov.br/dados/serie/bcdata.sgs.433/dados?formato=json'
df = pd.read_json(url)
df['data'] = pd.to_datetime(df['data'], dayfirst=True)
df
# Out:
#           data  valor
# 0   1980-01-01   6.62
# 1   1980-02-01   4.62
# 2   1980-03-01   6.04
# 3   1980-04-01   5.29
# 4   1980-05-01   5.70
# 5   1980-06-01   5.31
# 6   1980-07-01   5.55
# 7   1980-08-01   4.95
# 8   1980-09-01   4.23
# 9   1980-10-01   9.48
# 10  1980-11-01   6.67
# 11  1980-12-01   6.61
# 12  1981-01-01   6.84
# 13  1981-02-01   6.40
# 14  1981-03-01   4.97
# 15  1981-04-01   6.46
# 16  1981-05-01   5.56
# 17  1981-06-01   5.52
# 18  1981-07-01   6.26
# 19  1981-08-01   5.50
# 20  1981-09-01   5.26
# 21  1981-10-01   5.08
# 22  1981-11-01   5.27
# 23  1981-12-01   5.93
# 24  1982-01-01   6.97
# 25  1982-02-01   6.64
# 26  1982-03-01   5.71
# 27  1982-04-01   5.89
# 28  1982-05-01   6.66
# 29  1982-06-01   7.10
# ..         ...    ...
# 462 2018-07-01   0.33
# 463 2018-08-01  -0.09
# 464 2018-09-01   0.48
# 465 2018-10-01   0.45
# 466 2018-11-01  -0.21
# 467 2018-12-01   0.15
# 468 2019-01-01   0.32
# 469 2019-02-01   0.43
# 470 2019-03-01   0.75
# ...

# %%
fig, ax = plt.subplots(figsize=(16, 6))
sns.lineplot(y=df['valor'], x=df['data'])
ax.set(title = "Série Histórica IPCA", xlabel = "Ano")
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.ylabel('IPCA')
plt.grid(color='gray', linestyle='--', linewidth=0.5, axis='y')
